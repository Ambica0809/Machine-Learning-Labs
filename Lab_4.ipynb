# %% [markdown]
# ## **Loading the Necessary packages**

# %%
#Importing required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
import statsmodels.api as sm
import plotly.express as px #for plotting the scatter plot
import seaborn as sns #for plotting dataset in seaborn
sns.set(style="whitegrid")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Loading the dataset**

# %%
df = pd.read_csv("/content/DiamondsNew.csv")
print(df)
# Out:
#        Unnamed: 0        cut clarity color  ...  table     x     y     z
# 0               1      Ideal     SI2     E  ...   55.0  3.95  3.98  2.43
# 1               2    Premium     SI1     E  ...   61.0  3.89  3.84  2.31
# 2               3       Good     VS1     E  ...   65.0  4.05  4.07  2.31
# 3               4    Premium     VS2     I  ...   58.0  4.20  4.23  2.63
# 4               5       Good     SI2     J  ...   58.0  4.34  4.35  2.75
# ...           ...        ...     ...   ...  ...    ...   ...   ...   ...
# 53935       53936      Ideal     SI1     D  ...   57.0  5.75  5.76  3.50
# 53936       53937       Good     SI1     D  ...   55.0  5.69  5.75  3.61
# 53937       53938  Very Good     SI1     D  ...   60.0  5.66  5.68  3.56
# 53938       53939    Premium     SI2     H  ...   58.0  6.15  6.12  3.74
# 53939       53940      Ideal     SI2     D  ...   55.0  5.83  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
print(df.head())
# Out:
#    Unnamed: 0      cut clarity color  price  ...  carat  table     x     y     z
# 0           1    Ideal     SI2     E    326  ...   0.23   55.0  3.95  3.98  2.43
# 1           2  Premium     SI1     E    326  ...   0.21   61.0  3.89  3.84  2.31
# 2           3     Good     VS1     E    327  ...   0.23   65.0  4.05  4.07  2.31
# 3           4  Premium     VS2     I    334  ...   0.29   58.0  4.20  4.23  2.63
# 4           5     Good     SI2     J    335  ...   0.31   58.0  4.34  4.35  2.75
#
# [5 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'cut', 'clarity', 'color', 'price', 'depth', 'carat',
#        'table', 'x', 'y', 'z'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0'],axis=1)

# %%
print(df)
# Out:
#              cut clarity color  price  depth  carat  table     x     y     z
# 0          Ideal     SI2     E    326   61.5   0.23   55.0  3.95  3.98  2.43
# 1        Premium     SI1     E    326   59.8   0.21   61.0  3.89  3.84  2.31
# 2           Good     VS1     E    327   56.9   0.23   65.0  4.05  4.07  2.31
# 3        Premium     VS2     I    334   62.4   0.29   58.0  4.20  4.23  2.63
# 4           Good     SI2     J    335   63.3   0.31   58.0  4.34  4.35  2.75
# ...          ...     ...   ...    ...    ...    ...    ...   ...   ...   ...
# 53935      Ideal     SI1     D   2757   60.8   0.72   57.0  5.75  5.76  3.50
# 53936       Good     SI1     D   2757   63.1   0.72   55.0  5.69  5.75  3.61
# 53937  Very Good     SI1     D   2757   62.8   0.70   60.0  5.66  5.68  3.56
# 53938    Premium     SI2     H   2757   61.0   0.86   58.0  6.15  6.12  3.74
# 53939      Ideal     SI2     D   2757   62.2   0.75   55.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.head()
# Out:
#        cut clarity color  price  depth  carat  table     x     y     z
# 0    Ideal     SI2     E    326   61.5   0.23   55.0  3.95  3.98  2.43
# 1  Premium     SI1     E    326   59.8   0.21   61.0  3.89  3.84  2.31
# 2     Good     VS1     E    327   56.9   0.23   65.0  4.05  4.07  2.31
# 3  Premium     VS2     I    334   62.4   0.29   58.0  4.20  4.23  2.63
# 4     Good     SI2     J    335   63.3   0.31   58.0  4.34  4.35  2.75

# %%
df[['x','y','z']] =df[['x','y','z']].replace(0,np.NaN) 
df.dropna(inplace=True) 
df.isnull().sum()
# Out:
# cut        0
# clarity    0
# color      0
# price      0
# depth      0
# carat      0
# table      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
fig=px.scatter_matrix(df,dimensions=["depth","carat","table","x","y","z"])
fig.update_layout(
autosize=False,
width=1000,
height=1000    
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1fef8466-c82a-4418-9226-9e9469c00574" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1fef8466-c82a-4418-9226-9e9469c00574")) {
#                     Plotly.newPlot(
#                         '1fef8466-c82a-4418-9226-9e9469c00574',
# ...

# %%
df.head()
# Out:
#        cut clarity color  price  depth  carat  table     volume
# 0    Ideal     SI2     E    326   61.5   0.23   55.0  38.202030
# 1  Premium     SI1     E    326   59.8   0.21   61.0  34.505856
# 2     Good     VS1     E    327   56.9   0.23   65.0  38.076885
# 3  Premium     VS2     I    334   62.4   0.29   58.0  46.724580
# 4     Good     SI2     J    335   63.3   0.31   58.0  51.917250

# %%
df=df.drop(['Unnamed: 0', 'cut', 'color', 'clarity'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-643ac9be54a0> in <module>()
# ----> 1 df=df.drop(['Unnamed: 0', 'cut', 'color', 'clarity'],axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
print("Number of rows with 0 value in x is {}".format((df.x==0).sum()))
print("Number of rows with 0 value in y is {}".format((df.y==0).sum()))
print("Number of rows with 0 value in z is {}".format((df.z==0).sum()))
print("Number of rows with 0 value in carat is {}".format((df.carat==0).sum()))
print("Number of rows with 0 value in table is {}".format((df.table==0).sum()))
print("Number of rows with 0 value in depth is {}".format((df.depth==0).sum()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-cff34267645e> in <module>()
# ----> 1 print("Number of rows with 0 value in x is {}".format((df.x==0).sum()))
#       2 print("Number of rows with 0 value in y is {}".format((df.y==0).sum()))
#       3 print("Number of rows with 0 value in z is {}".format((df.z==0).sum()))
#       4 print("Number of rows with 0 value in carat is {}".format((df.carat==0).sum()))
#       5 print("Number of rows with 0 value in table is {}".format((df.table==0).sum()))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# ...

# %%
print(df)
# Out:
# None
